# %%
import pytest
import sys
import os

sys.dont_write_bytecode = True
os.environ["PYTHONPYCACHEPREFIX"] = "/tmp/__pycache__"

sys.path.append("/Workspace/Users/hugoboulenger@gmail.com/sales_pipeline/")

args = [
    "tests/",
    "-v",
    "-p", "no:cacheprovider",
    "-p", "no:warnings"
]

retcode = pytest.main(args)

if retcode != 0:
    raise Exception(f"pytest failed with exit code {retcode}")
else:
    print("All tests passed")
